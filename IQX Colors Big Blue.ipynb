# %% [markdown]
# # Circuit library
#
# They are all rendering as block.

# %%
import numpy as np
import matplotlib
# %matplotlib inline

# %%
from qiskit.circuit import QuantumCircuit, Gate

my_gate = Gate('abc', 2, [])

circuit = QuantumCircuit(2)
circuit.iswap(0, 1)
circuit.dcx(0, 1)
circuit.append(my_gate, [0, 1])
circuit.draw(output='mpl', style='legacy')

# %%
from qiskit.circuit import QuantumCircuit

circuit = QuantumCircuit(5)
circuit.i(0)
circuit.x(1)
circuit.y(2)
circuit.z(3)

circuit.h(0)
circuit.s(1)
circuit.sdg(2)
circuit.cx(0, 1)
circuit.cy(2, 3)
circuit.cz(1, 2)
circuit.swap(2, 3)
circuit.iswap(2, 3)
circuit.dcx(0, 1)

circuit.u1(0, 0)
circuit.u2(0, 0, 1)
circuit.u3(0, 0, 0, 2)


circuit.cu1(0, 0, 1)
circuit.cu3(0, 0, 0, 2, 3)

circuit.ch(3, 4)

circuit.crx(0, 0, 1)
circuit.cry(0, 1, 2)
circuit.crz(0, 2, 3)
circuit.r(0, 0, 3)
circuit.t(4)
circuit.tdg(4)
circuit.rx(0, 0)
circuit.ry(0, 1)
circuit.rz(0, 2)

circuit.rxx(0, 0, 1)
circuit.ryy(0, 1, 2)
circuit.rzz(0, 2, 3)
circuit.rzx(0, 0, 1)
circuit.ccx(0, 1, 2)
circuit.cswap(0, 1, 2)
circuit.rccx(0, 1, 2)
circuit.rcccx(0, 1, 2, 3)
circuit.ms([[0] * 5] * 5, [0, 1, 2, 3, 4])

circuit.reset(0)
circuit.barrier()

circuit.unitary(np.eye(4), [0, 1])
#circuit.initialize(np.eye(4)[0,:], [2, 3])
#circuit.isometry(np.eye(4), [], [1, 2])

circuit.draw(output='mpl')

# %%
circuit.draw(output='mpl', style=False)

# %%
from qiskit.circuit.library import QFT  # e.g. for the Quantum Fourier Transform
QFT(4).draw(output='mpl')

# %%
from qiskit.circuit.library import OR
OR(4).draw(output='mpl')

# %%
from qiskit.circuit.library import LinearPauliRotations
LinearPauliRotations(4, offset=2, slope=0.5).draw(output='mpl')

# %%
from qiskit.circuit.library import PiecewiseLinearPauliRotations
PiecewiseLinearPauliRotations(4, breakpoints=[0, 2], offsets=[2, 1], slopes=[0.5, -0.5]).draw(output='mpl')

# %%
from qiskit.circuit.library import QuantumVolume
QuantumVolume(4).decompose().draw(output='mpl')

# %%
QuantumVolume(4).decompose().decompose().draw(output='mpl')

# %%
from qiskit.circuit.library import EfficientSU2
EfficientSU2(3, entanglement='linear').draw(output='mpl')

# %%
from qiskit.circuit.library import WeightedAdder
WeightedAdder(3, [1,2,1]).draw(output='mpl')

# %%
from qiskit.circuit.library import IntegerComparator
IntegerComparator(3, 4).draw(output='mpl')

# %%
from qiskit import QuantumCircuit
circuit = QuantumCircuit(7)
circuit.mcx([0, 1, 2, 3], 4, ancilla_qubits=[5, 6], mode='v-chain')
circuit.decompose().draw(output='mpl')

# %%
circuit.decompose().decompose().draw(output='mpl')

# %%
from qiskit.circuit.library import ZZFeatureMap
ZZFeatureMap(3).draw(output='mpl')

# %%
from qiskit.circuit.library import ExcitationPreserving
ExcitationPreserving(3).draw(output='mpl')

# %%
from qiskit.circuit.library import IQP
IQP([[6, 5, 3], [5, 4, 5], [3, 5, 1]]).decompose().draw(output='mpl')

# %%
from qiskit.circuit.library import GMS
GMS(5, [[0.2] * 5] * 5).decompose().draw(output='mpl')

# %%
GMS(5, [[0.2] * 5] * 5).decompose().decompose().draw(output='mpl')

# %%
import qiskit.visualization.qcstyle as s

# %%
c = dict([(name, cls) for name, cls in s.__dict__.items() if issubclass(cls, s.MatplotlibDrawerStyle)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-389e75a4b414> in <module>
# ----> 1 c = dict([(name, cls) for name, cls in s.__dict__.items() if issubclass(cls, s.MatplotlibDrawerStyle)])
#
# <ipython-input-22-389e75a4b414> in <listcomp>(.0)
# ----> 1 c = dict([(name, cls) for name, cls in s.__dict__.items() if issubclass(cls, s.MatplotlibDrawerStyle)])
#
# TypeError: issubclass() arg 1 must be a class

# %%
issubclass(c['BWStyle'], s.MatplotlibDrawerStyle)

# %%
for name, cls in s.__dict__.items():
    if isinstance(cls, type):
        if issubclass(cls, s.MatplotlibDrawerStyle):
            print(name, cls)
